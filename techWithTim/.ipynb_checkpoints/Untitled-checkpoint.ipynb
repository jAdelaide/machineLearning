# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as pyplot
from matplotlib import style
import pickle

data = pd.read_csv("student-mat.csv", sep=";")

print(data.head())
print()

    # We only want these columns from the dataset, G# is a grade
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

print(data.head())
print()
print("[5 rows x 7 columns]")
print()

    # We want to predicted the 3rd grade
predict = "G3"

    # Makes a new array with all the data other than what we want to predict
X = np.array(data.drop([predict], 1))       # attributes
    # Makes a new array of just the data we want tot predict
y = np.array(data[predict])        # labels
    # Split this data into 4 arrays; a test and a train set for both X and y
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

            ################## This is only needed to train new models ######################################################

#     # Keeping track of the best model to only update with better versions
# best = 0
# for _ in range(300):
#     x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

#         # Use the linear regression model to find the line of best fit on the train data
#     linear = linear_model.LinearRegression()
#     linear.fit(x_train, y_train)
    
#     acc = linear.score(x_test, y_test)
#     if acc >= best:
#         print(acc, "  -  Best:", acc)
#         best = acc
#             # Makes a file if it doesn't already exist
#         with open("studentmodel.pickle", "wb") as f:
#                 # Saves the model as a pickle file
#             pickle.dump(linear, f)
#     else:
#         print(acc)

            #################################################################################################################
    
    # Opens the file in read mode
pickle_in = open("studentmodel.pickle", "rb")
    # Loads the model into a variable called 'linear'
linear = pickle.load(pickle_in)

    # Show the gradient coefficient and y intercept
print("Coeffs: ", + linear.coef_)
print("Intercept: ", + linear.intercept_)

    # Find the accuracy of our line using the test data
acc = linear.score(x_test, y_test)
print("Accuracy: ", + acc)
print()

    # Performing predictions based on the test data
predictions = linear.predict(x_test)

    # Print a prediction for each student, the array of the rest of that students data and then their actual G3
print("----------------------------------------------------------------------------")
print("----------------------------------------------------------------------------")
for x in range(len(predictions)):
    print("Prediction:", round(predictions[x], 1), "   Actual:", y_test[x], "   Error:", round(abs(predictions[x] - y_test[x]), 1), "   Used data:", x_test[x])

    # Plotting the graph using matplotlib
p = "G1"
style.use("ggplot")
pyplot.scatter(data[p], data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4
#
# [5 rows x 7 columns]
#
# 0.808869797986701   -  Best: 0.808869797986701
# 0.8627305196281455   -  Best: 0.8627305196281455
# 0.9018195074403864   -  Best: 0.9018195074403864
# 0.9182289135310507   -  Best: 0.9182289135310507
# 0.9422082270205205   -  Best: 0.9422082270205205
# 0.9509798528967668   -  Best: 0.9509798528967668
# 0.9595126375885605   -  Best: 0.9595126375885605
# Coeffs:  [ 0.15665634  0.98309954 -0.18456027 -0.29837824  0.03804943]
# Intercept:  -1.5901200129037516
# Accuracy:  0.7424718123564086
#
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# Prediction: 10.2    Actual: 11    Error: 0.8    Used data: [ 9 11  3  0  2]
# Prediction: 10.5    Actual: 12    Error: 1.5    Used data: [10 11  2  0  2]
# Prediction: 8.5    Actual: 8    Error: 0.5    Used data: [ 8  8  1  0 30]
# Prediction: 12.9    Actual: 13    Error: 0.1    Used data: [13 13  2  0  0]
# Prediction: 9.1    Actual: 12    Error: 2.9    Used data: [ 8 10  2  0  0]
# Prediction: 18.1    Actual: 18    Error: 0.1    Used data: [16 18  3  0  2]
# Prediction: 11.4    Actual: 12    Error: 0.6    Used data: [10 12  3  0  4]
# Prediction: 7.7    Actual: 8    Error: 0.3    Used data: [ 9  8  2  0 10]
# Prediction: 15.4    Actual: 15    Error: 0.4    Used data: [16 15  2  0  2]
# Prediction: 14.2    Actual: 15    Error: 0.8    Used data: [16 14  4  0  6]
# Prediction: 9.6    Actual: 10    Error: 0.4    Used data: [11 10  3  0  4]
# Prediction: 12.1    Actual: 13    Error: 0.9    Used data: [12 12  1  0  4]
# Prediction: 4.3    Actual: 6    Error: 1.7    Used data: [6 5 1 0 7]
# Prediction: 13.9    Actual: 14    Error: 0.1    Used data: [15 14  4  0  4]
# Prediction: 9.1    Actual: 0    Error: 9.1    Used data: [10 10  2  1  0]
# Prediction: 16.4    Actual: 16    Error: 0.4    Used data: [16 16  2  0  2]
# Prediction: 12.0    Actual: 11    Error: 1.0    Used data: [12 12  1  0  2]
# Prediction: 15.0    Actual: 15    Error: 0.0    Used data: [14 15  2  0  0]
# Prediction: 5.2    Actual: 6    Error: 0.8    Used data: [7 6 2 0 4]
# Prediction: 5.0    Actual: 6    Error: 1.0    Used data: [5 6 2 0 6]
# Prediction: 13.4    Actual: 13    Error: 0.4    Used data: [14 13  1  0  6]
# Prediction: 10.2    Actual: 11    Error: 0.8    Used data: [11 11  4  0  0]
# Prediction: 8.0    Actual: 8    Error: 0.0    Used data: [7 9 2 0 0]
# Prediction: 12.7    Actual: 13    Error: 0.3    Used data: [13 13  3  0  0]
# Prediction: 5.8    Actual: 6    Error: 0.2    Used data: [7 7 4 0 4]
# Prediction: 9.1    Actual: 0    Error: 9.1    Used data: [ 9 10  3  0  0]
# Prediction: 12.2    Actual: 11    Error: 1.2    Used data: [12 12  2  0 12]
# Prediction: 4.0    Actual: 6    Error: 2.0    Used data: [6 5 2 0 4]
# Prediction: 19.5    Actual: 20    Error: 0.5    Used data: [19 19  4  0  4]
# Prediction: 8.5    Actual: 9    Error: 0.5    Used data: [10  9  2  0  0]
# Prediction: 15.2    Actual: 14    Error: 1.2    Used data: [15 15  2  0  2]
# Prediction: 9.0    Actual: 10    Error: 1.0    Used data: [10 10  3  2  8]
# Prediction: 10.1    Actual: 10    Error: 0.1    Used data: [12 10  2  1 18]
# Prediction: 15.1    Actual: 15    Error: 0.1    Used data: [15 15  2  0  0]
# Prediction: 11.9    Actual: 12    Error: 0.1    Used data: [13 12  3  0  6]
# Prediction: 6.7    Actual: 8    Error: 1.3    Used data: [ 6  8  1  3 16]
# Prediction: 12.2    Actual: 13    Error: 0.8    Used data: [10 13  4  0  6]
# Prediction: -1.7    Actual: 0    Error: 1.7    Used data: [4 0 1 2 0]
# Prediction: 11.9    Actual: 13    Error: 1.1    Used data: [14 12  4  0  6]
# Prediction: 6.1    Actual: 8    Error: 1.9    Used data: [ 6  7  2  1 15]
